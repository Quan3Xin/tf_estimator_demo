# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pathlib
import os

# In[50]:

from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
gpus = tf.config.list_physical_devices("GPU")[0]
tf.config.experimental.set_memory_growth(gpus, True)

# %%
data_root_orig = "/root/quan/estir/raw-img/"
data_root = pathlib.Path(data_root_orig)
print(data_root)


traing_image_path = list(data_root.glob('*/*'))

traing_image_path = [str(path) for path in traing_image_path]
label_name = sorted(item.name for item in data_root.glob('*/')
                    if item.is_dir())
label_name
# Out:
# /root/quan/estir/raw-img
# ['cane',
#  'cavallo',
#  'elefante',
#  'farfalla',
#  'gallina',
#  'gatto',
#  'mucca',
#  'pecora',
#  'ragno',
#  'scoiattolo']

# %%
tst = traing_image_path[2]
cc =tf.io.read_file(tst)
img_tensor = tf.image.decode_jpeg(cc, channels=3)
print(img_tensor)
tf.image.convert_image_dtype(img_tensor, tf.float32)

# %%
train_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our training data
train_data_gen  = train_image_generator.flow_from_directory(batch_size=26,
                                                           directory=data_root_orig,
                                                           shuffle=True,
                                                           # repeat=True,
                                                           target_size=(160, 160),
                                                           class_mode='categorical')

# %%
for step, (x_batch_train, y_batch_train) in enumerate(train_data_gen):
    print(x_batch_train)

# %%
model = models.Sequential([
    Conv2D(16,
           3,
           padding='same', activation='relu',
           input_shape=(160,160,3)),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),

    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(128, 3, padding='same', activation='relu'),
    MaxPooling2D(),

    Dropout(0.2),
    Flatten(),
    Dense(120, activation='relu'),
    Dense(1)
])

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
             optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 160, 160, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 80, 80, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 80, 80, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 80, 80, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 40, 40, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 40, 40, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 120)               1536120
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 121
# =================================================================
# Total params: 1,633,681
# Trainable params: 1,633,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(traning_ds,  validation_data= validation_ds,epochs=10, steps_per_epoch=1000, validation_steps=10)
# Out:
# Train for 1000 steps, validate for 10 steps
# Epoch 1/10
#  312/1000 [========>.....................] - ETA: 4:08 - loss: 3.7276e-04 - accuracy: 1.0000

# %%
import matplotlib.pyplot as plt
print(model.history.history)
acc = model.history.history['accuracy']

loss = model.history.history['loss']

epochs_range = range(10)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
tf.keras.models.save_model(model,"/tmp/mobilenet/8/1")

# %%
test_img = tf.io.read_file(traing_image_path[100])
test_img = tf.image.decode_image(test_img, channels=3)
test_image = tf.image.convert_image_dtype(test_img, dtype=tf.float32).numpy()
predict_data  = np.resize(test_image, [1,160,160,3]).tolist()
predict_data

# %%
import json
import numpy
import requests



data = json.dumps({"signature_name": "serving_default",
                   "instances":predict_data})

headers = {"content-type": "application/json"}
json_response = requests.post('http://localhost:8501/v1/models/mobilenet1:predict',
                              data=data, headers=headers)
print(json_response.text)
predictions = numpy.array(json.loads(json_response.text)["predictions"])
predictions[0]

# %%
cat_dog_path_train = "/root/quan/estir/cats_and_dogs_filtered/train/"
cat_dog_path_test = "/root/quan/estir/cats_and_dogs_filtered/validation/"

cd_root_train = pathlib.Path(cat_dog_path_train)
cd_root_test = pathlib.Path(cat_dog_path_test)


cd_img_path = list(cd_root_train.glob('*/*'))
cd_img_path_test = list(cd_root_test.glob("*/*"))

all_image_path_validation = [str(path) for path in cd_img_path_test]

all_img_path = [str(path) for path in cd_img_path]
cd_name = sorted(item.name for item in cd_root_train.glob('*/')
                    if item.is_dir())

# %%
all_img_path
# Out:
# ['/root/quan/estir/cats_and_dogs_filtered/train/cats/cat
jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.301.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.866.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.786.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.587.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.65.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.880.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.522.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.3.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.509.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.86.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.241.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.77.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.675.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.677.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.212.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.540.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.710.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.93.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.235.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.854.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.127.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.862.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.269.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.403.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.607.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.926.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.407.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.234.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.79.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.637.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.591.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.500.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.105.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.421.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.94.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.640.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.868.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.56.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.890.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.64.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.686.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.120.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.577.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.517.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.85.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.569.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.765.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.383.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.35.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.420.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.673.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.438.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.389.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.954.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.250.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.121.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.318.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.141.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.657.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.261.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.648.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.51.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.644.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.689.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.773.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.169.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.398.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.929.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.200.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.266.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.861.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.960.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.668.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.302.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.46.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.294.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.967.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.339.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.523.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.315.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.595.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.338.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.598.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.539.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.344.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.761.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.816.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.907.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.471.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.353.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.847.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.573.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.306.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.978.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.178.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.142.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.613.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.874.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.570.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.752.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.808.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.690.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.307.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.448.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.308.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.776.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.545.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.599.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.555.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.601.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.435.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.161.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.784.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.192.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.995.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.664.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.270.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.230.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.24.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.759.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.384.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.898.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.682.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.138.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.335.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.309.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.320.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.430.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.627.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.125.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.414.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.95.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.662.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.16.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.222.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.999.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.63.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.818.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.734.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.59.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.527.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.332.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.535.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.968.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.770.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.365.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.702.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.942.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.101.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.590.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.593.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.567.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.820.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.26.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.493.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.151.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.621.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.903.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.373.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.791.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.680.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.275.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.492.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.863.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.635.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.844.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.425.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.190.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.406.jpg',
#  '/root/quan/estir/cats_and_dogs_filtered/train/cats/cat.216.jpg',
#  ...]

# %%
parent_path = os.path.dirname(all_img_path[0])
os.path.split(parent_path)[-1]

# %%
def decode_img(img_raw):
    img_tensor = tf.image.decode_jpeg(img_raw, channels=3)
    #img_tensor = (img_tensor/127.5) - 1
    #

    # 格式化0-1
    img = tf.image.convert_image_dtype(img_tensor, tf.float32)
    tf_fianl = tf.image.resize(img, [160, 160])
    return tf_fianl


def process_path(file_path):
     
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label


def get_label(file_path):
    # convert the path to a list of path components
    
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    return parts[-2] == label_name

# %%
_training_ds = tf.data.Dataset.from_tensor_slices(all_img_path)
_validation_ds  = tf.data.Dataset.from_tensor_slices(all_image_path_validation)

traning_ds =  _training_ds.map(process_path).shuffle(True).repeat().batch(batch_size=100)
validation_ds =_validation_ds.map(process_path).shuffle(True).repeat().batch(batch_size=100)

# %%
for i in validation_ds.take(2):
    print(i)
# Out:
# (<tf.Tensor: shape=(100, 100, 3), dtype=float32, numpy=
# array([[[0.87474227, 0.8707619 , 0.8629384 ],
#         [0.81976223, 0.85487986, 0.843174  ],
#         [0.63626033, 0.65233874, 0.6640054 ],
#         ...,
#         [0.18928887, 0.17752415, 0.1579163 ],
#         [0.2229608 , 0.2111961 , 0.19158825],
#         [0.20450972, 0.19274502, 0.17313716]],
#
#        [[0.86124384, 0.8572635 , 0.8494399 ],
#         [0.8538236 , 0.8889412 , 0.87723535],
#         [0.6441177 , 0.6601961 , 0.6718628 ],
#         ...,
#         [0.173843  , 0.16207829, 0.14247045],
#         [0.17596842, 0.16420372, 0.14459588],
#         [0.20564698, 0.19388227, 0.17427441]],
#
#        [[0.81468636, 0.81070596, 0.80288243],
#         [0.85208535, 0.887203  , 0.8754971 ],
#         [0.6483334 , 0.66441184, 0.6760785 ],
#         ...,
#         [0.18889466, 0.17712995, 0.15752211],
#         [0.18062721, 0.1688625 , 0.14925466],
#         [0.19113697, 0.17937225, 0.15976441]],
#
#        ...,
#
#        [[0.72439414, 0.71262944, 0.6538059 ],
#         [0.74782944, 0.73606473, 0.6772412 ],
#         [0.75301236, 0.7412476 , 0.68242407],
#         ...,
#         [0.6421728 , 0.6304081 , 0.595114  ],
#         [0.6585813 , 0.6468166 , 0.6115225 ],
#         [0.6526742 , 0.6409095 , 0.6134585 ]],
#
#        [[0.7575652 , 0.7418789 , 0.69652593],
#         [0.7397544 , 0.7240681 , 0.67871517],
#         [0.7468717 , 0.7311854 , 0.68583244],
#         ...,
#         [0.6354181 , 0.6217644 , 0.5865129 ],
#         [0.66114146, 0.6369258 , 0.6050435 ],
#         [0.6480149 , 0.63455284, 0.6036901 ]],
#
#        [[0.7167335 , 0.70104724, 0.6657531 ],
#         [0.72316784, 0.70748156, 0.67218745],
#         [0.83006614, 0.8143799 , 0.7790857 ],
#         ...,
#         [0.6300953 , 0.6026443 , 0.5712718 ],
#         [0.670779  , 0.62764174, 0.6041123 ],
#         [0.63413745, 0.61847067, 0.58317655]]], dtype=float32)>, <tf.Tensor: shape=(10,), dtype=bool, numpy=
# array([False, False, False, False, False, False, False, False, False,
#        False])>)
# (<tf.Tensor: shape=(100, 100, 3), dtype=float32, numpy=
# array([[[0.03137255, 0.03137255, 0.03137255],
#         [0.03137255, 0.03137255, 0.03137255],
#         [0.03137255, 0.03137255, 0.03137255],
#         ...,
#         [0.43674514, 0.46419612, 0.43282357],
#         [0.409451  , 0.4212157 , 0.39376473],
#         [0.4254118 , 0.4489412 , 0.40188238]],
#
#        [[0.03137255, 0.03137255, 0.03137255],
#         [0.03137255, 0.03137255, 0.03137255],
#         [0.03137255, 0.03137255, 0.03137255],
#         ...,
#         [0.43050984, 0.4579608 , 0.42658827],
#         [0.39780396, 0.40956867, 0.3821177 ],
#         [0.45141178, 0.47450984, 0.43658826]],
#
#        [[0.03137255, 0.03137255, 0.03137255],
#         [0.03137255, 0.03137255, 0.03137255],
#         [0.02294118, 0.02294118, 0.02294118],
#         ...,
#         [0.39352944, 0.42098042, 0.38960788],
#         [0.45313728, 0.46490198, 0.437451  ],
#         [0.4766667 , 0.49627453, 0.46882355]],
#
#        ...,
#
#        [[0.09411766, 0.09803922, 0.07843138],
#         [0.09411766, 0.09803922, 0.07843138],
#         [0.09411766, 0.09803922, 0.07843138],
#         ...,
#         [0.64078444, 0.6564707 , 0.65254915],
#         [0.627451  , 0.6431373 , 0.6392157 ],
#         [0.6190196 , 0.6190196 , 0.6190196 ]],
#
#        [[0.09411766, 0.09803922, 0.07843138],
#         [0.09062739, 0.09454897, 0.07494112],
#         [0.09760791, 0.10152948, 0.08192163],
#         ...,
#         [0.7129026 , 0.73251045, 0.7098437 ],
#         [0.61349   , 0.6326665 , 0.6182742 ],
#         [0.62309813, 0.63792175, 0.6340002 ]],
#
#        [[0.10050983, 0.1044314 , 0.08482355],
#         [0.09411766, 0.09803922, 0.07843138],
#         [0.09803922, 0.10196079, 0.08235294],
#         ...,
#         [0.6303529 , 0.64996076, 0.62643135],
#         [0.6720392 , 0.69164705, 0.66811764],
#         [0.6623138 , 0.6780001 , 0.6740785 ]]], dtype=float32)>, <tf.Tensor: shape=(10,), dtype=bool, numpy=
# array([False, False, False, False, False, False, False, False, False,
#        False])>)
