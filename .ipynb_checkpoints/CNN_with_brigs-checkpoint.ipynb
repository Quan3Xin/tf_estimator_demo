# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pathlib
import os

# In[50]:
import tensorflow_datasets as tfds


from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D,SeparableConv2D
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
gpus = tf.config.list_physical_devices("GPU")[0]
tf.config.experimental.set_memory_growth(gpus, True)

# %%
plt.figure()
plt.imshow(train_images[100])
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# ---------------------------------------------------
# NameError         Traceback (most recent call last)
# <ipython-input-4-8a7eb88366a6> in <module>
#       1 plt.figure()
# ----> 2 plt.imshow(train_images[100])
#       3 plt.colorbar()
#       4 plt.grid(False)
#       5 plt.show()
#
# NameError: name 'train_images' is not defined

# %%
predict_data = train_images[100]

# %%
def decode_img(img_raw):
    img_tensor = tf.image.decode_jpeg(img_raw, channels=3)
    print(img_tensor.shape)
    #img_tensor = (img_tensor/127.5) - 1
    tf_fianl = tf.image.resize(img_tensor, [150, 150])

    # 格式化0-1
    img = tf.image.convert_image_dtype(tf_fianl, tf.float32)
    img = (img / 127.5) - 1
    return img


def process_path(file_path):
    label = get_label(file_path)[0]
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label


def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    print(parts, "------")
    return parts[-2] == label_name
data_root_orig = "/data/birds/train/"
data_root = pathlib.Path(data_root_orig)

test_data_path = "/data/birds/test/"
test_path = pathlib.Path(test_data_path)
 
#vaildata 
valid_data_path = "/data/birds/valid/"
valid_data = pathlib.Path(valid_data_path)
valid_image_path = [str(path) for path in  list(valid_data.glob("*/*"))]

    
test_image_path = list(test_path.glob('*/*'))
test_image_path = [str(path) for path in test_image_path]

traing_image_path = list(data_root.glob('*/*'))
traing_image_path = [str(path) for path in traing_image_path]

label_name = sorted(item.name for item in test_path.glob('*/')
                    if item.is_dir())

# %%
traing_ds = tf.data.Dataset.list_files(str(data_root/'*/*')).map(parse_image).shuffle(buffer_size=2000).batch(batch_size=100).repeat()

validation_ds = tf.data.Dataset.list_files(str(valid_data/'*/*')).map(parse_image).shuffle(buffer_size=2000).batch(batch_size=100).repeat()
test_ds =  tf.data.Dataset.list_files(str(test_path/'*/*')).map(parse_image).shuffle(buffer_size=2000).batch(batch_size=100).repeat()

# for i in traing_ds.take(100):
#     c = i[0]
#     print(i[1])
#     plt.figure()
#     plt.imshow(c)
#     plt.colorbar()
#     #plt.grid(False)
#     plt.show()

# %%
traing_ds_path = pathlib.Path(data_root_orig)
trian_list_ds = tf.data.Dataset.list_files(str(traing_ds_path/'*/*')).map(parse_image)

def parse_image(filename):
  parts = tf.strings.split(filename, os.sep)
  label = parts[-2]

  image = tf.io.read_file(filename)
  image = tf.image.decode_jpeg(image)
  image = tf.image.convert_image_dtype(image, tf.float32)
  image = tf.image.resize(image, [150, 150])
  return image, label

#par_ds  = tf.data.Dataset.from_tensor_slices(traing_image_path).map(parse_image).shuffle(buffer_size=2000).batch(batch_size=100).repeat()

# %%
a = tf.io.read_file(traing_image_path[13]).numpy()
d = decode_img(a)

d = d.numpy()
#d = d.reshape(32,32,3).tolist()
#d
plt.figure()
plt.imshow(d)
plt.colorbar()
#plt.grid(False)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)

# %%
pre_dict = list()
for a in traing_image_path[::-1000]:
    print(a)
    a = tf.io.read_file(a).numpy()
    
    d = decode_img(a)
    d = d.numpy()
    d = d.reshape(1,150,150,3).tolist()
    pre_dict.append(d)
# Out:
# /data/birds/train/SPOONBILL/095.jpg
# (224, 224, 3)
# /data/birds/train/BLACK-THROATED SPARROW/126.jpg
# (224, 224, 3)
# /data/birds/train/AMERICAN KESTREL/110.jpg
# (224, 224, 3)
# /data/birds/train/NORTHERN GANNET/123.jpg
# (224, 224, 3)
# /data/birds/train/GREY PLOVER/072.jpg
# (224, 224, 3)
# /data/birds/train/PAINTED BUNTIG/077.jpg
# (224, 224, 3)
# /data/birds/train/BANANAQUIT/040.jpg
# (224, 224, 3)
# /data/birds/train/TURKEY VULTURE/064.jpg
# (224, 224, 3)
# /data/birds/train/BROWN NOODY/119.jpg
# (224, 224, 3)
# /data/birds/train/PINK ROBIN/108.jpg
# (224, 224, 3)
# /data/birds/train/D-ARNAUDS BARBET/193.jpg
# (224, 224, 3)
# /data/birds/train/LILAC ROLLER/082.jpg
# (224, 224, 3)
# /data/birds/train/CROW/037.jpg
# (224, 224, 3)
# /data/birds/train/MANDRIN DUCK/028.jpg
# (224, 224, 3)
# /data/birds/train/HORNBILL/125.jpg
# (224, 224, 3)
# /data/birds/train/EURASIAN MAGPIE/054.jpg
# (224, 224, 3)
# /data/birds/train/SORA/250.jpg
# (224, 224, 3)
# /data/birds/train/SHOEBILL/026.jpg
# (224, 224, 3)
# /data/birds/train/HOOPOES/040.jpg
# (224, 224, 3)
# /data/birds/train/YELLOW HEADED BLACKBIRD/004.jpg
# (224, 224, 3)
# /data/birds/train/MASKED BOOBY/126.jpg
# (224, 224, 3)
# /data/birds/train/PURPLE GALLINULE/076.jpg
# (224, 224, 3)
# /data/birds/train/BELTED KINGFISHER/077.jpg
# (224, 224, 3)
# /data/birds/train/COMMON HOUSE MARTIN/044.jpg
# (224, 224, 3)
# /data/birds/train/COMMON GRACKLE/056.jpg
# (224, 224, 3)
# /data/birds/train/GRAY CATBIRD/044.jpg
# (224, 224, 3)

# %%
# # shuffle the data
# pre_dict = pre_dict[::-10]
len(pre_dict)
# Out:
# 26

# %%
for i in traing_ds.take(1):
    d = i[0][0].numpy()
    
    #d = d.reshape(32,32,3).tolist()
    #d
    plt.figure()
    plt.imshow(d)
    #plt.grid(False)
    plt.show()
    #data = i[1]
    print(i[1][0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(False, shape=(), dtype=bool)

# %%
model = models.Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(SeparableConv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(SeparableConv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10))

# %%
model.summary()
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 74, 74, 32)        0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 72, 72, 64)        2400
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 34, 34, 128)       8896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36992)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2367552
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 2,380,394
# Trainable params: 2,380,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
history =model.fit(traing_ds,epochs=10, 
                   steps_per_epoch=1000,
                   validation_data=validation_ds, 
                   validation_steps=5)
# Out:
# Train for 1000 steps, validate for 5 steps
# Epoch 1/10

# %%
model.evaluate(test_ds, steps=100)
# Out:
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0864 - accuracy: 0.9946
# [0.08637970566749573, 0.9945946]

# %%
clothing_model = models.Sequential([
   Flatten(input_shape=(28, 28)),
   Dense(128, activation='relu'),
   Dense(10)
])
clothing_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
cloese_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ce999a0e0170> in <module>
#       7               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#       8               metrics=['accuracy'])
# ----> 9 cloese_model.summary()
#
# NameError: name 'cloese_model' is not defined

# %%
clothing_model.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 8s 135us/sample - loss: 3.0332 - accuracy: 0.6874
# Epoch 2/10
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.7095 - accuracy: 0.7333
# Epoch 3/10
# 60000/60000 [==============================] - 8s 142us/sample - loss: 0.6228 - accuracy: 0.7658
# Epoch 4/10
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.5515 - accuracy: 0.8070
# Epoch 5/10
# 60000/60000 [==============================] - 8s 133us/sample - loss: 0.5081 - accuracy: 0.8236
# Epoch 6/10
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.5090 - accuracy: 0.8251
# Epoch 7/10
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.4840 - accuracy: 0.8321
# Epoch 8/10
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.4808 - accuracy: 0.8353
# Epoch 9/10
# 60000/60000 [==============================] - 9s 144us/sample - loss: 0.4845 - accuracy: 0.8337
# Epoch 10/10
# 60000/60000 [==============================] - 9s 145us/sample - loss: 0.4689 - accuracy: 0.8391

# %%
clothing_model.evaluate(test_images, test_labels, steps=1000)
# Out:
# 10000/10000 [==============================] - 3s 294us/sample - loss: 0.5523 - accuracy: 0.8289
# [0.5522925056931562, 0.8289]

# %%
predict_data = predict_data.reshape(1,28,28)
print(predict_data.shape)
data_pre = cloese_model.predict(predict_data)
pre_num = np.argmax(data_pre)
print(pre_num)
class_names[pre_num]
# Out:
# (1, 28, 28)
# 3
# 'Dress'

# %%
new_model = models.Sequential([
   
    Conv2D(32, 3, padding='same', activation='relu', input_shape=(100, 100 ,3)),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(128, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1)
])
new_model.summary()
new_model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 100, 100, 32)      896
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 25, 25, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 25, 25, 128)       73856
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 18432)             0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               9437696
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 9,531,457
# Trainable params: 9,531,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
history =new_model.fit(traing_ds,epochs=10, steps_per_epoch=1000,validation_data=validation_ds, validation_steps=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6065027fce71> in <module>
# ----> 1 history =new_model.fit(traing_ds,epochs=10, steps_per_epoch=1000,validation_data=validation_ds, validation_steps=5)
#
# NameError: name 'new_model' is not defined

# %%
models.evaluate(validation_ds, steps=100)
# Out:
# 100/100 [==============================] - 7s 66ms/step - loss: 2.4437 - accuracy: 0.7240
# [2.4437484443187714, 0.724]

# %%
import matplotlib.pyplot as plt

def plot_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8,5))
    print(pd.DataFrame(history.history))
    plt.grid(True)
    plt.gca().set_ylim(0,3.2)
    plt.show()
plot_curves(history)

# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs_range = range(10)

# plt.figure(figsize=(8, 8))
# plt.subplot(1, 2, 1)
# plt.plot(epochs_range, acc, label='Training Accuracy')
# plt.plot(epochs_range, val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, loss, label='Training Loss')
# plt.plot(epochs_range, val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.show()
# acc = new_model.history.history['accuracy']
# val_acc = new_model.history.history['val_accuracy']

# loss = new_model.history.history['loss']
# val_loss = new_model.history.history['val_loss']

# epochs_range = range(10)

# plt.figure(figsize=(8, 8))
# plt.subplot(1, 2, 1)
# plt.plot(epochs_range, acc, label='Training Accuracy')
# plt.plot(epochs_range, val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, loss, label='Training Loss')
# plt.plot(epochs_range, val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.show()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.059901  0.996117   0.12340         0.992
# 1  0.059918  0.996116   0.12340         0.992
# 2  0.059918  0.996116   0.12340         0.992
# 3  0.059918  0.996116   0.09255         0.994
# 4  0.059918  0.996116   0.12340         0.992
# 5  0.059764  0.996126   0.09255         0.994
# 6  0.060073  0.996105   0.12340         0.992
# 7  0.059609  0.996136   0.12340         0.992
# 8  0.060227  0.996095   0.12340         0.992
# 9  0.059918  0.996116   0.06170         0.996

# %%
# pre_data = model.predict(pre_dict[0])
#np.argmax(pre_data)
#print(pre_dict[1])
#plt.imshow(pre_dict[1])
for i in pre_dict:
    pre_data = model.predict(pre_dict[0])
    print(pre_data)
    print(np.argmax(pre_data))
# Out:
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
# [[-0.70370555 -0.5365582  -0.20356709 -1.6748595  -0.56169474 -0.4296621
#   -0.64041096 -0.5956899  -1.1157427  -1.2996111 ]]
# 2
